# %%
from safetensors.torch import load_file

from datalib import InputPath

resolved_path = InputPath("s3://synthesia-rnd-prd-third-party-models/wan/dit/Wan2.1-I2V-14B-720P-bfloat16-DEBUG.safetensors").resolve()
wan_sd = load_file(resolved_path)

# %%
for key, _ in wan_sd.items():
    print(key)
# Out:
# final_layer.fc.bias
# final_layer.fc.weight
# final_layer.time_modulation_bias
# patch_embedder.fc.bias
# patch_embedder.fc.weight
# ref_embedder.proj.1.bias
# ref_embedder.proj.1.weight
# ref_embedder.proj.3.bias
# ref_embedder.proj.3.weight
# ref_embedder.proj.4.bias
# ref_embedder.proj.4.weight
# text_embedder.0.bias
# text_embedder.0.weight
# text_embedder.2.bias
# text_embedder.2.weight
# time_embedder.mlp.fc1.bias
# time_embedder.mlp.fc1.weight
# time_embedder.mlp.fc2.bias
# time_embedder.mlp.fc2.weight
# time_projection.1.bias
# time_projection.1.weight
# transformer_blocks.0.cross_attn.fc_k.bias
# transformer_blocks.0.cross_attn.fc_k.weight
# transformer_blocks.0.cross_attn.fc_k_cond.bias
# transformer_blocks.0.cross_attn.fc_k_cond.weight
# transformer_blocks.0.cross_attn.fc_out.bias
# transformer_blocks.0.cross_attn.fc_out.weight
# transformer_blocks.0.cross_attn.fc_q.bias
# transformer_blocks.0.cross_attn.fc_q.weight
# transformer_blocks.0.cross_attn.fc_v.bias
# ...
