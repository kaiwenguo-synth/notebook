# %%
from safetensors.torch import load_file

from datalib import InputPath

resolved_path = InputPath("s3://synthesia-rnd-prd-third-party-models/wan/dit/Wan2.1-I2V-1.3B-multires-bfloat16.safetensors").resolve()
wan_fan_sd = load_file(resolved_path)

resolved_path = InputPath("s3://synthesia-rnd-prd-third-party-models/wan/dit/Wan2.1-T2V-1.3B-480P-bfloat16.safetensors").resolve()
wan_t2v_sd = load_file(resolved_path)

# %%
for key, value in wan_fan_sd.items():
    print(key, value)
# Out:
# final_layer.fc.bias tensor([ 0.0026, -0.0173, -0.0062, -0.0054, -0.0245, -0.0051, -0.0026, -0.0199,
#         -0.0048,  0.0109, -0.0045,  0.0056,  0.0032, -0.0613,  0.0148, -0.0061,
#          0.0089,  0.0137, -0.0056,  0.0027, -0.0190,  0.0267, -0.0176,  0.0047,
#          0.0156, -0.0239,  0.0198, -0.0216, -0.0092, -0.0233, -0.0111,  0.0013,
#          0.0149, -0.0425,  0.0079,  0.0325,  0.0063,  0.0037, -0.0003, -0.0310,
#         -0.0151, -0.0171,  0.0139,  0.0002, -0.0044, -0.0522,  0.0212, -0.0078,
#          0.0069, -0.0093,  0.0231,  0.0106,  0.0088,  0.0018, -0.0176,  0.0295,
#         -0.0166,  0.0066,  0.0168, -0.0271,  0.0066, -0.0017, -0.0212, -0.0239],
#        dtype=torch.bfloat16)
# final_layer.fc.weight tensor([[ 0.0035,  0.0008, -0.0014,  ..., -0.0040, -0.0071,  0.0234],
#         [ 0.0142,  0.0012,  0.0030,  ..., -0.0090,  0.0067, -0.0046],
#         [-0.0052, -0.0026,  0.0032,  ...,  0.0021,  0.0032, -0.0089],
#         ...,
# ...
