# %%
from datalib import OutputPath

# local_storage = OutputPath("/tmp/datalib_cache/_gs/synthesia-rnd-euw1-experiments/ditwo/kaiwen/PG004/cc3_v1/checkpoints")
local_storage = OutputPath("gs://synthesia-rnd-euw1-experiments/ditwo/kaiwen/PG004/cc3_v1/checkpoints")

local_storage.commit()
# Out:
# WARNING:google.auth._default:Authentication failed using Compute Engine authentication due to unavailable metadata server.
# WARNING:google.auth._default:Authentication failed using Compute Engine authentication due to unavailable metadata server.
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[4], line 4
#       1 from datalib import OutputPath
#       3 # local_storage = OutputPath("/tmp/datalib_cache/_gs/synthesia-rnd-euw1-experiments/ditwo/kaiwen/PG004/cc3_v1/checkpoints")
# ----> 4 local_storage = OutputPath("gs://synthesia-rnd-euw1-experiments/ditwo/kaiwen/PG004/cc3_v1/checkpoints")
#       6 local_storage.commit()
#
# File ~/dev/nb/.venv/lib/python3.12/site-packages/datalib/filesystem/path.py:144, in OutputPath.__new__(cls, path, *args, **kwargs)
#     142 if isinstance(path, str):
#     143     check_path(path)
# ...
